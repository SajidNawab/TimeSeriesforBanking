# %%
import numpy as np
import pandas as pd

# %%
import pandas as pd
df_hbl = pd.read_csv("allHBL_Data.csv")
df_hbl
# Out:
#             Date    Open    High     Low   Turnover   Close company
# 0     2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL
# 1     2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL
# 2     2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL
# 3     2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL
# 4     2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL
# ...          ...     ...     ...     ...        ...     ...     ...
# 2589  2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL
# 2590  2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL
# 2591  2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL
# 2592  2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL
# 2593  2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL
#
# [2594 rows x 7 columns]

# %%
df_hbl.dtypes
# Out:
# Date         object
# Open        float64
# High        float64
# Low         float64
# Turnover    float64
# Close       float64
# company      object
# dtype: object

# %% [markdown]
# Some observations about the `date` column:
# - Notice that the `date` column has a `dtype` of `object`.
#
# - This means that `pandas` is interpreting it as a text column, rather than a date.
#
# - Formatting problems with dates are common in data analysis.
#
# - We'll address this issue a later in the tutorial.

# %% [markdown]
# ## Simple Row Slicing

# %% [markdown]
# The simplest way to slice a `DataFrame` is to use square brackets: `[]`.  The syntax `df[i:j]` will generate a `DataFrame` who's first row is the `i`th row of `df` and who's last row is the `(j-1)`th row of `df`.
#
# Let's demonstrate this with a couple of examples:

# %%
df_hbl[10:20]
# Out:
#           Date    Open    High     Low  Turnover   Close company
# 10  2011-01-17  126.70  128.00  126.34  195832.0  126.70     HBL
# 11  2011-01-18  126.79  127.44  125.45   75393.0  126.79     HBL
# 12  2011-01-19  125.58  127.12  124.10  158779.0  125.58     HBL
# 13  2011-01-20  124.49  125.25  122.83   54899.0  124.49     HBL
# 14  2011-01-21  123.03  125.25  123.00   73781.0  123.03     HBL
# 15  2011-01-24  123.80  124.65  123.30   28629.0  123.80     HBL
# 16  2011-01-25  123.58  124.85  123.40   70998.0  123.58     HBL
# 17  2011-01-26  123.50  124.01  122.00  202293.0  123.50     HBL
# 18  2011-01-27  122.16  125.10  123.10  523617.0  122.16     HBL
# 19  2011-01-28  123.62  124.96  123.00  192270.0  123.62     HBL

# %% [markdown]
# Starting with the 3rd row, and ending with the 6th row:

# %%
df_hbl[3:7]
# Out:
#          Date    Open    High     Low  Turnover   Close company
# 3  2011-01-06  124.93  125.89  123.75  773913.0  124.93     HBL
# 4  2011-01-07  124.98  126.06  124.69  376749.0  124.98     HBL
# 5  2011-01-10  124.99  126.80  123.00  166214.0  124.99     HBL
# 6  2011-01-11  123.56  124.50  122.75  329849.0  123.56     HBL

# %% [markdown]
# The full `DataFrame`:

# %%
df_hbl # full dataframe
# Out:
#             Date    Open    High     Low   Turnover   Close company
# 0     2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL
# 1     2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL
# 2     2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL
# 3     2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL
# 4     2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL
# ...          ...     ...     ...     ...        ...     ...     ...
# 2589  2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL
# 2590  2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL
# 2591  2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL
# 2592  2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL
# 2593  2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL
#
# [2594 rows x 7 columns]

# %% [markdown]
# ## `DataFrame` Index

# %% [markdown]
# Let's take a look at the `columns` index of `df_hbl`:

# %%
df_hbl.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Turnover', 'Close', 'company'], dtype='object')

# %%
type(df_hbl.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df_hbl.index
# Out:
# RangeIndex(start=0, stop=2594, step=1)

# %%
type(df_hbl.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# ## Indexing with `DataFrame.iloc`

# %% [markdown]
# The indexer attribute `DataFrame.iloc` can be used to access rows and columns using their implicit row and column numbers.
#
# Here is an example of `iloc` that retrieves the first two rows of `df_hbl`:

# %%
df_hbl.iloc[1:4][['Open','Close']]
# Out:
#      Open   Close
# 1  119.49  119.49
# 2  121.87  121.87
# 3  124.93  124.93

# %% [markdown]
# Notice, that because we didn't specify any particular column numbers, the code above retrieves all columns.
#
# The following code grabs just the first three rows and the first three columns of the first two rows of `df_hbl`:

# %%
r=[15]
c=[1]
df_hbl.iloc[r,c]
# Out:
#      Open
# 15  123.8

# %% [markdown]
# We can also supply `.iloc` with `lists` rather than ranges to specify custom sets of columns and rows:

# %%
lst_row = [0, 2] # first and third rows
lst_col = [0, 6] # date and adjusted columns
df_hbl.iloc[0:10, [0,6]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11004/2044878090.py in <module>
#       1 lst_row = [0, 2] # first and third rows
#       2 lst_col = [0, 6] # date and adjusted columns
# ----> 3 df_hbl.iloc[0:10, [0,6]]
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1095             if self._is_scalar_access(key):
#    1096                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097             return self._getitem_tuple(key)
#    1098         else:
#    1099             # we by definition only have the 0th axis
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1592
#    1593     def _getitem_tuple(self, tup: tuple):
# -> 1594         tup = self._validate_tuple_indexer(tup)
# ...

# %% [markdown]
# Using `lists` as a means of indexing is sometimes referred to as *fancy indexing*.

# %% [markdown]
# ## Indexing with `DataFrame.loc`

# %% [markdown]
# Rather than using the implicit row or column numbers, it is often more useful to access data by using the explicit row or column indices.
#
# As a preliminary step, let's first recast the `date` column as a `datetime`.  This can be done easily by using `pandas` built-in `to_datetime()` method:

# %%
df_hbl['Date'] = pd.to_datetime(df_hbl['Date']) 
df_hbl.dtypes
# Out:
# Date        datetime64[ns]
# Open               float64
# High               float64
# Low                float64
# Turnover           float64
# Close              float64
# company             object
# dtype: object

# %%
df_hbl['Year']=df_hbl['Date'].dt.year
df_hbl['Month']=df_hbl['Date'].dt.month
df_hbl
# Out:
#            Date    Open    High     Low   Turnover   Close company  Year
# 0    2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL  2011  \
# 1    2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL  2011
# 2    2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL  2011
# 3    2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL  2011
# 4    2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL  2011
# ...         ...     ...     ...     ...        ...     ...     ...   ...
# 2589 2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL  2021
# 2590 2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL  2021
# 2591 2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL  2021
# 2592 2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL  2021
# 2593 2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL  2021
#
#       Month
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %% [markdown]
# Next we'll use the `DataFrame.set_index()` method to set the `date` column as our new index.  We are doing this because we ultimately want to use our dates as an index to access the data.

# %%
df_hbl.set_index('Date',inplace=True)
df_hbl.head()
# Out:
#               Open    High     Low   Turnover   Close company
# Date
# 2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL
# 2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL
# 2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL
# 2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL
# 2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL

# %% [markdown]
# To see the effect of the above code, we can have a look at the `index` of `df_hbl`.

# %%
df_hbl.loc['2011-01-10']
# df_hbl.index
# Out:
# Open          124.99
# High           126.8
# Low            123.0
# Turnover    166214.0
# Close         124.99
# company          HBL
# Name: 2011-01-10, dtype: object

# %% [markdown]
# Notice that `date` is no longer column of `df_hbl`:

# %%
df_hbl.columns
# Out:
# Index(['Open', 'High', 'Low', 'Turnover', 'Close', 'company'], dtype='object')

# %% [markdown]
# Now that we have successful set the row `index` of `df_hbl` to be the `date`, let's see how we can use this `index` to access the data via `.loc`.
#
# Here is an example of how we can grab a slice of rows, associated with a date-range:

# %%
df_hbl.loc['2018-12-21':'2018-12-28']
# Out:
#               Open    High     Low   Turnover   Close company
# Date
# 2018-12-21  125.00  127.00  120.80  3164400.0  124.78     HBL
# 2018-12-24  124.40  125.00  122.15   373200.0  124.59     HBL
# 2018-12-26  124.50  126.80  124.00   705900.0  124.39     HBL
# 2018-12-27  126.00  126.39  119.04   715300.0  125.30     HBL
# 2018-12-28  121.79  122.74  117.25  1909900.0  122.56     HBL

# %% [markdown]
# If we want to select only the `Turnover` and `Close` columns for these dates, we would type the following:

# %%
df_hbl.loc['2018-12-21':'2018-12-28', ['Turnover', 'Close']]
# Out:
#              Turnover   Close
# Date
# 2018-12-21  3164400.0  124.78
# 2018-12-24   373200.0  124.59
# 2018-12-26   705900.0  124.39
# 2018-12-27   715300.0  125.30
# 2018-12-28  1909900.0  122.56

# %%
df_hbl['intraday_range'] = df_hbl['High'] - df_hbl['Low']
df_hbl
# Out:
#               Open    High     Low   Turnover   Close company  intraday_range
# Date
# 2011-01-03  121.94  121.00  116.80   510969.0  121.94     HBL            4.20
# 2011-01-04  119.49  122.30  119.50   627959.0  119.49     HBL            2.80
# 2011-01-05  121.87  126.45  121.40  1506848.0  121.87     HBL            5.05
# 2011-01-06  124.93  125.89  123.75   773913.0  124.93     HBL            2.14
# 2011-01-07  124.98  126.06  124.69   376749.0  124.98     HBL            1.37
# ...            ...     ...     ...        ...     ...     ...             ...
# 2021-07-26  129.98  130.45  128.10   607740.0  128.76     HBL            2.35
# 2021-07-27  127.80  131.95  127.80  2267549.0  131.31     HBL            4.15
# 2021-07-28  131.90  131.90  129.55   802489.0  130.80     HBL            2.35
# 2021-07-29  131.00  131.00  128.50   531104.0  128.93     HBL            2.50
# 2021-07-30  129.00  129.47  126.00  2104560.0  126.67     HBL            3.47
#
# [2594 rows x 7 columns]

# %%
df= pd.read_csv('combined.csv')
df
# Out:
#             Date   Open   High    Low  Turnover  Close company
# 0       1/3/2011  68.23  67.94  65.10   2378598  68.23     UBL
# 1       1/4/2011  65.59  67.10  65.55   3237772  65.59     UBL
# 2       1/5/2011  66.61  67.70  65.75   2947076  66.61     UBL
# 3       1/6/2011  65.99  66.80  66.15   1205505  65.99     UBL
# 4       1/7/2011  66.53  67.60  66.20   1651016  66.53     UBL
# ...          ...    ...    ...    ...       ...    ...     ...
# 10349  7/26/2021   8.26   8.35   8.17   1538000   8.21     BOP
# 10350  7/27/2021   8.25   8.60   8.20  10885500   8.41     BOP
# 10351  7/28/2021   8.48   8.48   8.25   2241000   8.28     BOP
# 10352  7/29/2021   8.30   8.30   8.20   1400000   8.22     BOP
# 10353  7/30/2021   8.21   8.35   8.17   3124000   8.20     BOP
#
# [10354 rows x 7 columns]

# %%
print(df['company'].unique())
print(df['company'].unique().size)
# Out:
# ['UBL' 'HBL' 'ABL' 'BOP']
# 4

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
df['Date']
# Out:
# 0       2011-01-03
# 1       2011-01-04
# 2       2011-01-05
# 3       2011-01-06
# 4       2011-01-07
#            ...
# 10349   2021-07-26
# 10350   2021-07-27
# 10351   2021-07-28
# 10352   2021-07-29
# 10353   2021-07-30
# Name: Date, Length: 10354, dtype: datetime64[ns]

# %%
print(df['Date'].min())
print(df['Date'].max())
# Out:
# 2011-01-03 00:00:00
# 2021-07-30 00:00:00

# %%
df['year'] = df['Date'].dt.year
df['month'] = df['Date'].dt.month
df[['Date', 'year', 'month']].head()
df
# Out:
#             Date   Open   High    Low  Turnover  Close company  year  month
# 0     2011-01-03  68.23  67.94  65.10   2378598  68.23     UBL  2011      1
# 1     2011-01-04  65.59  67.10  65.55   3237772  65.59     UBL  2011      1
# 2     2011-01-05  66.61  67.70  65.75   2947076  66.61     UBL  2011      1
# 3     2011-01-06  65.99  66.80  66.15   1205505  65.99     UBL  2011      1
# 4     2011-01-07  66.53  67.60  66.20   1651016  66.53     UBL  2011      1
# ...          ...    ...    ...    ...       ...    ...     ...   ...    ...
# 10349 2021-07-26   8.26   8.35   8.17   1538000   8.21     BOP  2021      7
# 10350 2021-07-27   8.25   8.60   8.20  10885500   8.41     BOP  2021      7
# 10351 2021-07-28   8.48   8.48   8.25   2241000   8.28     BOP  2021      7
# 10352 2021-07-29   8.30   8.30   8.20   1400000   8.22     BOP  2021      7
# 10353 2021-07-30   8.21   8.35   8.17   3124000   8.20     BOP  2021      7
#
# [10354 rows x 9 columns]

# %%
# Groupby
gk = df.groupby('year')
gk.get_group(2012)
# gk.first(5)
# gk.first(4)  
# gk.head() #print 5 entries of each month
# gk.apply(lambda x:x.to_csv(f'{x.name}.csv'))
# gk.to_csv('new.csv')
# Out:
#            Date   Open   High    Low  Turnover  Close company  year  month
# 248  2012-01-02  52.39  53.60  52.55     21845  52.39     UBL  2012      1
# 249  2012-01-03  53.45  55.65  53.01    188431  53.45     UBL  2012      1
# 250  2012-01-04  55.46  55.01  53.40    298453  55.46     UBL  2012      1
# 251  2012-01-05  53.90  54.36  53.25    114153  53.90     UBL  2012      1
# 252  2012-01-06  53.82  54.90  53.76    555020  53.82     UBL  2012      1
# ...         ...    ...    ...    ...       ...    ...     ...   ...    ...
# 8251 2012-12-21   9.50   9.76   9.47   3155500   9.50     BOP  2012     12
# 8252 2012-12-24   9.52   9.65   9.40   1170500   9.52     BOP  2012     12
# 8253 2012-12-26   9.44   9.60   9.35   1827500   9.44     BOP  2012     12
# 8254 2012-12-27   9.36   9.48   9.24   1217500   9.36     BOP  2012     12
# 8255 2012-12-28   9.28   9.94   9.27   6904500   9.28     BOP  2012     12
#
# [989 rows x 9 columns]

# %%
gkk = df.groupby(['company', 'year','month'])
gkk.first()
gkk.to_csv('grouped.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11004/1246401645.py in <module>
#       1 gkk = df.groupby(['company', 'year','month'])
#       2 gkk.first()
# ----> 3 gkk.to_csv('grouped.csv')
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     950             return self[attr]
#     951
# --> 952         raise AttributeError(
#     953             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     954         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_csv'

# %%
def save_to_csv(x):
    x.to_csv(f'{x.name}.csv')

# gkk=df.groupby(['company', 'year','month'])
gkk.apply(save_to_csv)
# gkk.to_csv('grouped_data.csv')
# gkk.get_group(('UBL',2012,2))
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_volume = df.groupby(['company', 'year', 'month'])['Turnover'].agg([np.max]).reset_index()
df_volume.rename(columns={'amax':'Max'}, inplace=True)
df_volume.head(20)
# Out:
#    company  year  month      Max
# 0      ABL  2011      1  1200042
# 1      ABL  2011      2   450198
# 2      ABL  2011      3   613880
# 3      ABL  2011      4   682890
# 4      ABL  2011      5   281682
# 5      ABL  2011      6  1275072
# 6      ABL  2011      7   237957
# 7      ABL  2011      8   359122
# 8      ABL  2011      9   376374
# 9      ABL  2011     10   979080
# 10     ABL  2011     11    78523
# 11     ABL  2011     12   277098
# 12     ABL  2012      1   229208
# 13     ABL  2012      2   442561
# 14     ABL  2012      3   483144
# 15     ABL  2012      4   813881
# 16     ABL  2012      5   626264
# 17     ABL  2012      6  1122668
# 18     ABL  2012      7   475149
# 19     ABL  2012      8   962500

# %%
df.loc[df.groupby('company')['Turnover'].idxmin()][['Date','company','Turnover']]
# Out:
#            Date company  Turnover
# 5324 2011-07-14     ABL         1
# 8165 2012-08-10     BOP     61500
# 2989 2012-07-27     HBL      2200
# 244  2011-12-27     UBL      4177

# %%
# # create a line plot for each company with their Yearly turnover (summed)
import matplotlib.pyplot as plt 
plt.figure(figsize=(16,9))
df_volume = df.groupby(['company', 'year'])['Turnover'].sum().reset_index()
df_volume[df_volume['company']=='ABL']['Turnover']
years=list(df_volume['year'].unique())
abl=list(df_volume[df_volume['company']=='ABL']['Turnover'])
ubl=list(df_volume[df_volume['company']=='UBL']['Turnover'])
hbl=list(df_volume[df_volume['company']=='HBL']['Turnover'])
bop=list(df_volume[df_volume['company']=='BOP']['Turnover'])

plt.plot(years, abl,marker='o',color='g',markerfacecolor='r',linestyle='--',label='ABL')
plt.plot(years, ubl,marker='v',color='r',markerfacecolor='b',linestyle='-',label='UBL')
plt.plot(years, bop,marker='*',color='m',markerfacecolor='y',linestyle=':',label='BOP')
plt.plot(years, hbl,marker='.',color='b',markerfacecolor='m',linestyle='--',label='HBL')


plt.title("Turnover Graph")
plt.xlabel("Turnover (in Millions)")
plt.ylabel("Years")
plt.legend()
plt.show()
